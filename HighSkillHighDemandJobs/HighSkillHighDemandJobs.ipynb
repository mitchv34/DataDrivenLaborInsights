# %% [markdown]
# # Identifying High-Skill, High-Demand Jobs for Career Counseling
# ### Step 1: Explore O*NET Data
#
# This notebook will:
# 1. Download the required O*NET data files.
# 2. Load and examine the data structure.
# 3. Explore job-related skills, knowledge, and work activities.

# %%
# Importing necessary libraries
import pandas as pd

# %%
# Define file paths for the downloaded O*NET files
DATA_PATH = "https://www.onetcenter.org/dl_files/database/db_29_1_text/"

# Load the Skills.txt file
skills_data = pd.read_csv(DATA_PATH + "Skills.txt", sep="\t", encoding='latin1')  # Tab-separated file

# Display the first few rows of the skills data
print("Skills Data Overview:")
skills_data.head()

# %%
# Load the Knowledge.txt file
knowledge_data = pd.read_csv(DATA_PATH + "Knowledge.txt", sep="\t", encoding='latin1')

# Display the first few rows of the knowledge data
print("Knowledge Data Overview:")
knowledge_data.head()
# Out:
# Knowledge Data Overview:
#   O*NET-SOC Code Element ID                   Element Name Scale ID  \
# 0     11-1011.00    2.C.1.a  Administration and Management       IM
# 1     11-1011.00    2.C.1.a  Administration and Management       LV
# 2     11-1011.00    2.C.1.b                 Administrative       IM
# 3     11-1011.00    2.C.1.b                 Administrative       LV
# 4     11-1011.00    2.C.1.c       Economics and Accounting       IM
#
#    Data Value     N  Standard Error  Lower CI Bound  Upper CI Bound  \
# 0        4.78  28.0          0.1102          4.5564          5.0000
# 1        6.50  28.0          0.2130          6.0666          6.9409
# 2        2.42  28.0          0.4651          1.4662          3.3749
# 3        2.69  28.0          0.8678          0.9078          4.4690
# 4        4.04  28.0          0.3480          3.3246          4.7526
#
#   Recommend Suppress Not Relevant     Date Domain Source
# 0                  N          NaN  08/2023     Incumbent
# 1                  N            N  08/2023     Incumbent
# 2                  N          NaN  08/2023     Incumbent
# 3                  N            N  08/2023     Incumbent
# 4                  N          NaN  08/2023     Incumbent

# %%
# Load the Work Context.txt file
work_context_data = pd.read_csv(DATA_PATH + "Work%20Context.txt", sep="\t", encoding='latin1')

# Display the first few rows of the work context data
print("Work Context Data Overview:")
work_context_data.head()
# Out:
# Work Context Data Overview:
#   O*NET-SOC Code   Element ID     Element Name Scale ID  Category  Data Value  \
# 0     11-1011.00  4.C.1.a.2.c  Public Speaking       CX       NaN        3.07
# 1     11-1011.00  4.C.1.a.2.c  Public Speaking      CXP       1.0        0.13
# 2     11-1011.00  4.C.1.a.2.c  Public Speaking      CXP       2.0       39.49
# 3     11-1011.00  4.C.1.a.2.c  Public Speaking      CXP       3.0       33.07
# 4     11-1011.00  4.C.1.a.2.c  Public Speaking      CXP       4.0        7.79
#
#       N  Standard Error  Lower CI Bound  Upper CI Bound Recommend Suppress  \
# 0  37.0          0.2851          2.4923          3.6486                  N
# 1  37.0          0.1370          0.0160          1.0770                  N
# 2  37.0         11.0101         20.4073         62.4299                  N
# 3  37.0          7.1359         20.4456         48.7245                  N
# 4  37.0          4.3613          2.4093         22.4457                  N
#
#    Not Relevant     Date Domain Source
# 0           NaN  08/2023     Incumbent
# 1           NaN  08/2023     Incumbent
# 2           NaN  08/2023     Incumbent
# 3           NaN  08/2023     Incumbent
# 4           NaN  08/2023     Incumbent

# %%
# Load the Work Activities.txt file
work_activities_data = pd.read_csv(DATA_PATH + "Work%20Activities.txt", sep="\t", encoding='latin1')

# Display the first few rows of the work activities data
print("Work Activities Data Overview:")
work_activities_data.head()
# Out:
# Work Activities Data Overview:
#   O*NET-SOC Code Element ID                                      Element Name  \
# 0     11-1011.00  4.A.1.a.1                               Getting Information
# 1     11-1011.00  4.A.1.a.1                               Getting Information
# 2     11-1011.00  4.A.1.a.2  Monitoring Processes, Materials, or Surroundings
# 3     11-1011.00  4.A.1.a.2  Monitoring Processes, Materials, or Surroundings
# 4     11-1011.00  4.A.1.b.1          Identifying Objects, Actions, and Events
#
#   Scale ID  Data Value     N  Standard Error  Lower CI Bound  Upper CI Bound  \
# 0       IM        4.56  29.0          0.1559          4.2369          4.8756
# 1       LV        4.89  30.0          0.1727          4.5393          5.2458
# 2       IM        4.25  30.0          0.2125          3.8130          4.6823
# 3       LV        5.21  30.0          0.3872          4.4133          5.9971
# 4       IM        4.23  29.0          0.1544          3.9180          4.5507
#
#   Recommend Suppress Not Relevant     Date Domain Source
# 0                  N          NaN  08/2023     Incumbent
# 1                  N            N  08/2023     Incumbent
# 2                  N          NaN  08/2023     Incumbent
# 3                  N            N  08/2023     Incumbent
# 4                  N          NaN  08/2023     Incumbent

# %% [markdown]
# ### Data Notes
# - Each dataset includes a `O*NET-SOC Code` column to identify occupations.
# - The `Element Name` column provides descriptive labels for skills, knowledge, etc.
# - `Data Value` columns often represent importance or level ratings.
# - `Skills` and `Knowledge` are listed with importance and level ratings (numeric values).
#
# Next, we will merge and analyze these data to calculate job similarities.
